# %%
import sys
sys.path.append('../')  

from data.dummy_datasets import create_cube
from utils.plots import *
from utils.operations import E2G
import networkx as nx

# %%
length = 3
coord, E = create_cube(length, 10.0)
G = E2G(E, pow(length, 3))
life_mask = np.zeros(coord.shape[0])
life_mask[coord.shape[0] // 2] = 1
plot_3d_G(G, coord, "cube G", transparent=True, show_edges=True, angle=30, node_alpha=life_mask)
