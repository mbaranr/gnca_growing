# %%
import sys
sys.path.append('../')  

from data.datasets import create_cube
from utils.plots import *

import networkx as nx

# %%
length = 4
coord, E = create_cube(length, 2.0)
G = E2G(E, pow(length, 3))
plot_3d_G(G, coord, "cube G", transparent=True, show_edges=True)
