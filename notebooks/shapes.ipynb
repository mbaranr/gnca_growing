# %%
import sys
sys.path.append('../')  

from data.dummy_datasets import *
from utils.plots import *
from utils.operations import E2G

# %%
length = 7
coords, E = create_3d_canvas(length, 1)
G = E2G(E, pow(length, 3))
# target = create_cube_mask(length)
# target = create_pyramid_mask(length)
# target = create_cylinder_mask(length, 4, length)
target = create_cuboid_mask(length, 2)

# %%
plot_3d_G(G, coords, "shape", transparent=True, show_edges=False, angle=30, node_alpha=target, axis_range=1)
# Out:
# <Axes3D: title={'center': 'shape'}>

# %%
length = 32
coords, E  = create_2d_canvas(length, 1)
G= E2G(E, length*length)
target = create_image_mask("../res/T.png", length)

# %%
plot_2d_G(G, coords, "shape", transparent=True, show_edges=True, node_alpha=target, axis_range=1.1)
# Out:
# <Axes: title={'center': 'shape'}>
